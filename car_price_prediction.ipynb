# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import Imputer

# %%
# importing the dataset

data_test = pd.read_csv('D:\\Dataset\\Participants_Data_Used_Cars\\test.csv')
data_train = pd.read_csv('D:\\Dataset\\Participants_Data_Used_Cars\\Train.csv')


data = pd.concat([data_train,data_test],axis=0,sort=False)
data_train
# Out:
#                                                   Name    Location  Year  \
# 0                               Maruti Wagon R LXI CNG      Mumbai  2010
# 1                     Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                         Honda Jazz V     Chennai  2011
# 3                                    Maruti Ertiga VDI     Chennai  2012
# 4                      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5                      Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6                               Nissan Micra Diesel XV      Jaipur  2013
# 7                    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8                  Volkswagen Vento Diesel Comfortline        Pune  2013
# 9                       Tata Indica Vista Quadrajet LS     Chennai  2012
# 10                                    Maruti Ciaz Zeta       Kochi  2018
# 11                         Honda City 1.5 V AT Sunroof     Kolkata  2012
# ...

# %%
data.shape
# Out:
# (7253, 13)

# %%
data_test.shape,data_train.shape
# Out:
# ((1234, 12), (6019, 13))

# %%
a=np.arange(1,7254)
data=data.set_index(a)

# %%
data.drop('New_Price',axis=1,inplace=True)
data.drop('Price',axis=1,inplace=True)

data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 1            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 2  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 3                      Honda Jazz V     Chennai  2011              46000
# 4                 Maruti Ertiga VDI     Chennai  2012              87000
# 5   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats
# 1       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 2    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 3    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 4    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 5    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0

# %%
data.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               46
# Power                46
# Seats                53
# dtype: int64

# %%
data.replace('null bhp',np.nan,inplace=True)

# %%
data.isnull().sum()
# Out:
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage                2
# Engine                46
# Power                175
# Seats                 53
# dtype: int64

# %%
#removing suffix
   

# new data frame with split value columns 
new = data["Mileage"].str.split(" ", n = 0, expand = True) 
new1 = data['Engine'].str.split(" ",n=0,expand=True)
new2 = data['Power'].str.split(" ",n=0,expand=True)
# making separate first name column from new data frame 
data["Mileage"]= new[0]  
data['Engine']=new1[0]
data['Power']=new2[0]
  
# df display 
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 1            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 2  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 3                      Honda Jazz V     Chennai  2011              46000
# 4                 Maruti Ertiga VDI     Chennai  2012              87000
# 5   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type Mileage Engine  Power  Seats
# 1       CNG       Manual      First    26.6    998  58.16    5.0
# 2    Diesel       Manual      First   19.67   1582  126.2    5.0
# 3    Petrol       Manual      First    18.2   1199   88.7    5.0
# 4    Diesel       Manual      First   20.77   1248  88.76    7.0
# 5    Diesel    Automatic     Second    15.2   1968  140.8    5.0

# %%
data.isnull().sum()
# Out:
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage                2
# Engine                46
# Power                175
# Seats                 53
# dtype: int64

# %%
#above three feature has converted into strings to will have convert them back into float

# %%
data["Mileage"]=data["Mileage"].astype(float)
data["Engine"]=data["Engine"].astype(float)
data["Power"]=data["Power"].astype(float)

# %%
##MIssing value treatment

# %%
data['Mileage'].mean()
# Out:
# 18.14158047165911

# %%
int(data['Engine'].mean())
# Out:
# 1616

# %%
int(data['Seats'].mean())
# Out:
# 5

# %%
data['Power'].mean()
# Out:
# 112.76521404351419

# %%
data['Power'].fillna(data['Power'].mean(),inplace=True)
data['Engine'].fillna(int(data['Engine'].mean()),inplace=True)
data['Mileage'].fillna(data['Mileage'].mean(),inplace=True)
data['Seats'].fillna(int(data['Seats'].mean()),inplace=True)

# %%
data.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# dtype: int64

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 1            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 2  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 3                      Honda Jazz V     Chennai  2011              46000
# 4                 Maruti Ertiga VDI     Chennai  2012              87000
# 5   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats
# 1       CNG       Manual      First    26.60   998.0   58.16    5.0
# 2    Diesel       Manual      First    19.67  1582.0  126.20    5.0
# 3    Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 4    Diesel       Manual      First    20.77  1248.0   88.76    7.0
# 5    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0

# %%
data['Owner_Type'].unique()
# Out:
# array(['First', 'Second', 'Fourth & Above', 'Third'], dtype=object)

# %%
#Owner type is in categorical form but it should be in order


data['Owner_Type'] = data['Owner_Type'].astype('category',categories=['Fourth & Above','Third','Second','First'],ordered=True).cat.codes
# Out:
# C:\Users\mukul\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3325: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data['Owner_Type'].unique()
# Out:
# array([3, 2, 0, 1], dtype=int64)

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 1            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 2  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 3                      Honda Jazz V     Chennai  2011              46000
# 4                 Maruti Ertiga VDI     Chennai  2012              87000
# 5   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission  Owner_Type  Mileage  Engine   Power  Seats
# 1       CNG       Manual           3    26.60   998.0   58.16    5.0
# 2    Diesel       Manual           3    19.67  1582.0  126.20    5.0
# 3    Petrol       Manual           3    18.20  1199.0   88.70    5.0
# 4    Diesel       Manual           3    20.77  1248.0   88.76    7.0
# 5    Diesel    Automatic           2    15.20  1968.0  140.80    5.0

# %%
# year is in continuous form but it should be in categorical
data["Year"]=data["Year"].astype(str)

# %%
data['Year'].mean()
# Out:
# inf

# %%
#list of categorical features
d=list(data.loc[:,data.dtypes=='object'].columns.values)

# %%
d
# Out:
# ['Name', 'Location', 'Year', 'Fuel_Type', 'Transmission']

# %%
print(data['Kilometers_Driven'].max(),data['Kilometers_Driven'].min())
# Out:
# 6500000 171

# %%
data_test.shape,data_train.shape
# Out:
# ((1234, 12), (6019, 13))

# %%
len(data_train)
# Out:
# 6019

# %%
data1=pd.get_dummies(data,columns=['Name','Location','Year','Fuel_Type','Transmission'],drop_first=True)

# %%
data1.shape
# Out:
# (7253, 2083)

# %%
data1
# Out:
#       Kilometers_Driven  Owner_Type  Mileage  Engine   Power  Seats  \
# 1                 72000           3    26.60   998.0   58.16    5.0
# 2                 41000           3    19.67  1582.0  126.20    5.0
# 3                 46000           3    18.20  1199.0   88.70    5.0
# 4                 87000           3    20.77  1248.0   88.76    7.0
# 5                 40670           2    15.20  1968.0  140.80    5.0
# 6                 75000           3    21.10   814.0   55.20    5.0
# 7                 86999           3    23.08  1461.0   63.10    5.0
# 8                 36000           3    11.36  2755.0  171.50    8.0
# 9                 64430           3    20.54  1598.0  103.60    5.0
# 10                65932           2    22.30  1248.0   74.00    5.0
# 11                25692           3    21.56  1462.0  103.25    5.0
# 12                60000           3    16.80  1497.0  116.30    5.0
# 13                64424           3    25.20  1248.0   74.00    5.0
# ...

# %%
data_train.replace('null bhp',np.nan,inplace=True)

# %% [markdown]
# # train_data

# %%
#removing suffix


# new data frame with split value columns 
new = data_train["Mileage"].str.split(" ", n = 0, expand = True) 
new1 = data_train['Engine'].str.split(" ",n=0,expand=True)
new2 = data_train['Power'].str.split(" ",n=0,expand=True)
# making separate first name column from new data frame 
data_train["Mileage"]= new[0]  
data_train['Engine']=new1[0]
data_train['Power']=new2[0]
  
# df display 
data_train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-acd596cd5025> in <module>
#       3
#       4 # new data frame with split value columns
# ----> 5 new = data_train["Mileage"].str.split(" ", n = 0, expand = True)
#       6 new1 = data_train['Engine'].str.split(" ",n=0,expand=True)
#       7 new2 = data_train['Power'].str.split(" ",n=0,expand=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5061         if (name in self._internal_names_set or name in self._metadata or
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
# ...

# %%
data_train["Mileage"]=data_train["Mileage"].astype(float)
data_train["Engine"]=data_train["Engine"].astype(float)
data_train["Power"]=data_train["Power"].astype(float)

# %%
data_train.corr()
# Out:
#                        Year  Kilometers_Driven   Mileage    Engine     Power  \
# Year               1.000000          -0.173048  0.321565 -0.052197  0.014525
# Kilometers_Driven -0.173048           1.000000 -0.065253  0.091068  0.033503
# Mileage            0.321565          -0.065253  1.000000 -0.597699 -0.537729
# Engine            -0.052197           0.091068 -0.597699  1.000000  0.866185
# Power              0.014525           0.033503 -0.537729  0.866185  1.000000
# Seats              0.012333           0.083113 -0.308226  0.393337  0.101562
# Price              0.305327          -0.011493 -0.306593  0.658354  0.772566
#
#                       Seats     Price
# Year               0.012333  0.305327
# Kilometers_Driven  0.083113 -0.011493
# Mileage           -0.308226 -0.306593
# Engine             0.393337  0.658354
# Power              0.101562  0.772566
# Seats              1.000000  0.052225
# Price              0.052225  1.000000

# %%
data1=data1.drop(['Engine','Kilometers_Driven','Mileage'],axis=1)
X_train = data1[:len(data_train)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-136-525bea095bfa> in <module>
# ----> 1 data1=data1.drop(['Engine','Kilometers_Driven','Mileage'],axis=1)
#       2 X_train = data1[:len(data_train)]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %%
data1.shape
# Out:
# (7253, 2081)

# %%
#data1=data1.drop(['Engine'],axis=1)

X_test=data1[len(data_train):]

# %%
from sklearn.model_selection import KFold,cross_val_score
from sklearn.metrics import make_scorer,r2_score

# %%
#cross validation

def test_model(model):
    cv = KFold(n_splits=3,shuffle=True,random_state=0)
    r2=make_scorer(r2_score)
    r2_val_score = cross_val_score(model,X_train,y_train,cv=cv,scoring=r2)
    score=[r2_val_score.mean()]
    return score

# %%
import sklearn.linear_model as linear_model

# %%
LR=linear_model.LinearRegression()
test_model(LR)
# Out:
# [-1.760841784380305e+16]

# %%
rid=linear_model.Ridge()
test_model(rid)
# Out:
# [0.8176720231834466]

# %%
lasso=linear_model.Lasso(alpha=1e-4)
test_model(lasso)
# Out:
# C:\Users\mukul\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8005.016075891156, tolerance: 50.48147662291875
#   positive)
# C:\Users\mukul\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8625.352047832617, tolerance: 49.33850512323948
#   positive)
# C:\Users\mukul\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4029.306940238197, tolerance: 50.83230721463743
#   positive)
# [0.8019369752611593]

# %%
rid.fit(X_train,y_train)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
from sklearn.ensemble import GradientBoostingRegressor,BaggingRegressor

# %%
gb=GradientBoostingRegressor(n_estimators=1000,learning_rate=0.1,loss='ls',random_state=0)
test_model(gb)
# Out:
# [0.8649587037008328]

# %%
br= BaggingRegressor(base_estimator=None,n_estimators=1000,random_state=0)
test_model(br)
# Out:
# [0.8553382938148797]

# %%
gb.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=1000,
#                           n_iter_no_change=None, presort='auto', random_state=0,
#                           subsample=1.0, tol=0.0001, validation_fraction=0.1,
#                           verbose=0, warm_start=False)

# %%
br.fit(X_train,y_train)
# Out:
# BaggingRegressor(base_estimator=None, bootstrap=True, bootstrap_features=False,
#                  max_features=1.0, max_samples=1.0, n_estimators=1000,
#                  n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                  warm_start=False)

# %%
#y_pred=br.predict(X_test).round(2)
y_pred=rid.predict(X_test).round(2)

# %%
y_predict=gb.predict(X_test).round(2)

# %%
for i in y_pred:
    print(i)
# Out:
# 2.29
# 0.02
# 16.92
# 7.25
# 6.28
# 12.56
# 21.44
# 0.45
# 3.14
# 11.24
# 21.6
# 5.9
# 3.16
# 2.4
# 5.65
# 16.73
# 29.49
# 0.3
# 11.83
# 8.17
# 6.69
# -0.26
# 3.86
# 3.63
# 8.37
# -0.25
# -1.8
# 6.72
# 9.44
# 1.3
# 4.13
# 6.68
# 0.54
# 10.52
# 3.19
# 6.33
# 9.92
# 12.11
# 5.1
# 20.96
# 9.62
# 21.8
# 16.68
# 9.65
# 7.87
# 7.94
# 4.73
# 18.36
# 10.99
# 19.39
# 6.52
# 5.56
# 7.06
# 24.84
# 5.37
# 8.74
# 8.7
# 6.01
# 2.96
# 1.7
# 2.58
# 6.27
# 4.35
# 4.83
# 5.74
# 3.69
# 3.56
# 11.4
# -0.36
# 4.71
# 7.24
# 4.24
# 5.91
# 9.54
# 2.91
# 0.67
# 2.99
# 7.69
# 4.31
# 5.84
# 28.72
# 22.56
# 9.37
# 6.93
# 7.06
# 19.36
# 5.89
# -0.94
# 1.73
# 9.39
# 1.64
# 12.17
# 4.14
# 4.85
# -0.44
# 7.41
# 7.41
# 11.74
# 1.17
# 6.59
# 5.93
# -0.13
# 31.9
# 4.52
# 3.14
# 1.68
# 15.35
# 6.12
# 7.11
# 8.28
# 29.33
# 3.29
# 29.96
# 6.23
# 4.42
# 12.73
# 7.21
# 24.85
# 6.92
# 10.7
# 10.63
# 8.88
# 6.17
# 29.08
# 0.14
# 29.33
# 44.11
# 25.99
# 6.38
# 5.43
# 7.27
# 1.48
# 5.81
# -4.93
# 6.41
# 4.14
# 35.51
# 3.89
# ...

# %%
len(y_predict)
# Out:
# 1234

# %%
b=data_train['Price']

# %%
len(X_test)
# Out:
# 1234

# %%
data.corr()
# Out:
#                        Year  Kilometers_Driven   Mileage    Engine     Power  \
# Year               1.000000          -0.187859  0.322437 -0.054226  0.012855
# Kilometers_Driven -0.187859           1.000000 -0.069122  0.094764  0.030074
# Mileage            0.322437          -0.069122  1.000000 -0.585015 -0.501818
# Engine            -0.054226           0.094764 -0.585015  1.000000  0.853067
# Power              0.012855           0.030074 -0.501818  0.853067  1.000000
# Seats              0.010849           0.089837 -0.302202  0.398942  0.094830
#
#                       Seats
# Year               0.010849
# Kilometers_Driven  0.089837
# Mileage           -0.302202
# Engine             0.398942
# Power              0.094830
# Seats              1.000000

# %%
plt.scatter(data['Engine'][:len(data_train)],b)
#plt.plot(X, Y_pred, color='red')

# %%
plt.scatter(data['Power'][:len(data_train)],b)

# %%
data["Owner_Type"].value_counts()
# Out:
# First             5952
# Second            1152
# Third              137
# Fourth & Above      12
# Name: Owner_Type, dtype: int64

# %%
data_train

# %%
plt.hist(data_train['Price'])
# Out:
# (array([5.098e+03, 6.190e+02, 2.000e+02, 6.400e+01, 2.900e+01, 5.000e+00,
#         2.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([  0.44 ,  16.396,  32.352,  48.308,  64.264,  80.22 ,  96.176,
#         112.132, 128.088, 144.044, 160.   ]),
#  <a list of 10 Patch objects>)
